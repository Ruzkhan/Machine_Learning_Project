# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
car_crashes_data = sns.load_dataset("car_crashes")

# %%
car_crashes_data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
car_crashes_data.shape
# Out:
# (51, 8)

# %%
car_crashes_data.info
# Out:
# <bound method DataFrame.info of     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
car_crashes_data.dtypes
# Out:
# total             float64
# speeding          float64
# alcohol           float64
# not_distracted    float64
# no_previous       float64
# ins_premium       float64
# ins_losses        float64
# abbrev             object
# dtype: object

# %%
car_crashes_data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# So, Here we dont have any null values. So we are good to proceed

# %%
car_crashes_data.duplicated().sum()
# Out:
# 0

# %%
car_crashes_data.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
car_crashes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
sns.histplot(car_crashes_data['total'],kde=True)
plt.show()

# %%
#Lets plot year
sns.distplot(car_crashes_data['alcohol'])

plt.show()

# %%
sns.histplot(car_crashes_data['ins_premium'],kde=True)
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
sns.scatterplot(x='total',y='speeding',data=car_crashes_data)
plt.show()

# %%
sns.histplot(car_crashes_data['total'],kde=True)
plt.show()

# %%
sns.relplot(x='speeding',y='not_distracted',data=car_crashes_data)
plt.show()

# %%
import numpy as np
from scipy.stats import zscore

# %%
plt.boxplot(car_crashes_data['total'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bcb3cc1c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bcb3cd21f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bcb3cc1940>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bcb3cd27c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bcb3cd2a90>],
#  'means': []}

# %%
plt.boxplot(car_crashes_data['speeding'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bcb3d35400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bcb3d359a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bcb3d35130>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bcb3d35f40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bcb3d41250>],
#  'means': []}

# %%
plt.boxplot(car_crashes_data['alcohol'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bcb3da1250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bcb3da17f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bcb3d92f40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bcb3da1d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bcb3dae0a0>],
#  'means': []}

# %%
plt.boxplot(car_crashes_data['not_distracted'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bcb3df5e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bcb3e06430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bcb3df5b80>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bcb3e069d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bcb3e06ca0>],
#  'means': []}

# %%
plt.boxplot(car_crashes_data['no_previous'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bcb3c53940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bcb3c77310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bcb3c53670>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bcb3c77dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bcb3c3cee0>],
#  'means': []}

# %% [markdown]
# # observation

# %% [markdown]
# alcohol have outlier and not ditracted have outlier

# %%
car_crashes_data
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
features = car_crashes_data[['total','speeding','alcohol','not_distracted','no_previous','ins_premium','ins_losses']]

# %%
import pandas as pd

# Identify numeric columns
numeric_columns = car_crashes_data.select_dtypes(include=[float]).columns

# Perform outlier detection only on numeric columns
df1 = car_crashes_data[~((car_crashes_data[numeric_columns] < (Q1 - 1.5 * IQR)) | (car_crashes_data[numeric_columns] > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 7>()
#       4 numeric_columns = car_crashes_data.select_dtypes(include=[float]).columns
#       6 # Perform outlier detection only on numeric columns
# ----> 7 df1 = car_crashes_data[~((car_crashes_data[numeric_columns] < (Q1 - 1.5 * IQR)) | (car_crashes_data[numeric_columns] > (Q3 + 1.5 * IQR))).any(axis=1)]
#
# NameError: name 'Q1' is not defined

# %%
# Assuming you have already calculated Q1, Q3, and IQR
# Define your DataFrame and numeric_columns as you did
numeric_columns = car_crashes_data.select_dtypes(include=[float]).columns

# Perform outlier detection only on numeric columns
df1 = car_crashes_data[~((car_crashes_data[numeric_columns] < (Q1 - 1.5 * IQR)) | (car_crashes_data[numeric_columns] > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 6>()
#       3 numeric_columns = car_crashes_data.select_dtypes(include=[float]).columns
#       5 # Perform outlier detection only on numeric columns
# ----> 6 df1 = car_crashes_data[~((car_crashes_data[numeric_columns] < (Q1 - 1.5 * IQR)) | (car_crashes_data[numeric_columns] > (Q3 + 1.5 * IQR))).any(axis=1)]
#
# NameError: name 'Q1' is not defined

# %%
# 1st quantile
Q1=features.quantile(0.25)

# 3rd quantile
Q3=features.quantile(0.75)

# IQR
IQR=Q3 - Q1

df1=car_crashes_data[~((car_crashes_data < (Q1 - 1.5 * IQR)) |(car_crashes_data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df1.shape
# Out:
# (47, 8)

# %%
# Checking the the data loss
data_loss = (50-47)/50*100
data_loss
# Out:
# 6.0

# %% [markdown]
# So, in IQR Method we can see that we lost out 6.0% data . lets move foreward with Z score if we dont get better result with Z Score Method then we choose IQR Method.

# %%
import numpy as np
from scipy.stats import zscore

# %%
# Using zscore to remove outliers

z=np.abs(zscore(features))

z
# Out:
#        total  speeding   alcohol  not_distracted  no_previous  ins_premium  \
# 0   0.737446  1.168148  0.439938        1.002301     0.277692     0.580083
# 1   0.565936  1.212695  0.211311        0.608532     0.807258     0.943258
# 2   0.688443  0.756709  0.187615        0.459357     1.033141     0.070876
# 3   1.619498  0.483614  0.547408        1.676052     1.951700     0.337701
# 4   0.928653  0.399524  0.891763        0.594276     0.891968     0.048418
# 5   0.536630  0.016920  0.630095        0.633698     0.291042     0.291479
# 6   1.222671  0.015114  0.583369        0.935632     1.381293     1.029641
# 7   0.100408  0.579520  0.015644        0.116657     0.545426     1.421281
# 8   2.423242  1.497695  1.923831        1.718689     2.174301     2.191759
# 9   0.516933  0.620259  0.177686        0.648402     0.756823     1.547371
# 10  0.046601  1.018184  0.576360        0.279272     0.134972     0.148365
# ...

# %%
# Creating new dataframe
new_df = car_crashes_data[(z<3).all(axis=1)] 
new_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
new_df['abbrev']=lab_enc.fit_transform(new_df['abbrev'])

# %%
new_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
car_crashes_data.tail(20)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 31   18.4     3.496    4.968          12.328       18.032       869.85
# 32   12.3     3.936    3.567          10.824        9.840      1234.31
# 33   16.8     6.552    5.208          15.792       13.608       708.24
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 35   14.1     3.948    4.794          13.959       11.562       697.73
# 36   19.9     6.368    5.771          18.308       18.706       881.51
# 37   12.8     4.224    3.328           8.576       11.520       804.71
# 38   18.2     9.100    5.642          17.472       16.016       905.99
# 39   11.1     3.774    4.218          10.212        8.769      1148.99
# 40   23.9     9.082    9.799          22.944       19.359       858.97
# 41   19.4     6.014    6.402          19.012       16.684       669.31
# 42   19.5     4.095    5.655          15.990       15.795       767.91
# ...

# %%
# Checking the correlation
cor = new_df.corr()
cor
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.627277  0.844041        0.811276     0.953473
# speeding        0.627277  1.000000  0.723903        0.609018     0.581799
# alcohol         0.844041  0.723903  1.000000        0.696024     0.773229
# not_distracted  0.811276  0.609018  0.696024        1.000000     0.727685
# no_previous     0.953473  0.581799  0.773229        0.727685     1.000000
# ins_premium    -0.163672 -0.073040 -0.115338       -0.132670    -0.122804
# ins_losses      0.004235 -0.061563 -0.057972       -0.032460     0.030289
# abbrev          0.037416  0.080106  0.138441       -0.006727    -0.037124
#
#                 ins_premium  ins_losses    abbrev
# total             -0.163672    0.004235  0.037416
# speeding          -0.073040   -0.061563  0.080106
# alcohol           -0.115338   -0.057972  0.138441
# not_distracted    -0.132670   -0.032460 -0.006727
# ...

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(15,15))
sns.heatmap(new_df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':15},cmap="YlGnBu")
plt.yticks(rotation=0);

# %%
plt.figure(figsize=(22,7))
new_df.corr()['total'].sort_values(ascending=False).drop(['total']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=10)
plt.ylabel('target',fontsize=10)
plt.title('correlation between label and feature using bar plot',fontsize=20)
plt.show()

# %%
x = new_df.drop("total", axis=1)
y = new_df["total"]

# %%
x.shape
# Out:
# (50, 7)

# %%
y.shape
# Out:
# (50,)

# %%
x.skew()
# Out:
# speeding          0.441774
# alcohol           0.983264
# not_distracted   -0.105105
# no_previous      -0.079853
# ins_premium       0.761564
# ins_losses        0.126409
# abbrev            0.000000
# dtype: float64

# %% [markdown]
# Here , i am setting the threshold for +/-1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x.head()
# Out:
#    speeding   alcohol  not_distracted  no_previous  ins_premium  ins_losses  \
# 0  1.162307  0.547190        1.094558     0.319776    -0.604267    0.410510
# 1  1.206444 -0.165363        0.683096     0.861101     0.923445   -0.043063
# 2  0.754668  0.271115        0.527219     1.092000     0.048560   -1.002279
# 3 -0.474200  0.664777        1.798583     2.030954    -0.361190    0.301083
# 4 -0.390887 -0.909869       -0.573757    -0.875854    -0.071076    1.246468
#
#      abbrev
# 0 -1.628453
# 1 -1.697749
# 2 -1.489862
# 3 -1.559158
# 4 -1.420566

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#    VIF values        Features
# 0    2.213749        speeding
# 1    3.806608         alcohol
# 2    2.474992  not_distracted
# 3    3.234771     no_previous
# 4    1.714204     ins_premium
# 5    1.674577      ins_losses
# 6    1.117262          abbrev

# %%
#Lets create with random forest
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 5):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.9618213397386365 on Random State 3

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
regressors = {
    
    'Random Forest' : LinearRegression(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]
results
# Out:
#                  MAE    MSE     RMSE  R2-score
# Random Forest  0.695  0.711  0.84298     0.962

# %%
plt.scatter(y_test,pred)
plt.xlabel('Actual Data')
plt.ylabel('Predicted Data')
plt.title('Linear Regression Graph')
plt.tight_layout()

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
# from sklearn.model_selection import cross_val_score
for j in range(2,10):
    isscore = cross_val_score(lr,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 2
# Cross validation score is:- 90.56139518552142
# accuracy_score is:- 96.18213397386364
#
#
# At cv:- 3
# Cross validation score is:- 92.93683617826773
# accuracy_score is:- 96.18213397386364
#
#
# At cv:- 4
# Cross validation score is:- 93.60001253754767
# accuracy_score is:- 96.18213397386364
#
#
# At cv:- 5
# Cross validation score is:- 91.12975585656584
# accuracy_score is:- 96.18213397386364
#
#
# At cv:- 6
# Cross validation score is:- 90.73538485586278
# accuracy_score is:- 96.18213397386364
#
#
# At cv:- 7
# Cross validation score is:- 93.25303357821898
# accuracy_score is:- 96.18213397386364
#
#
# At cv:- 8
# Cross validation score is:- 90.4629783115105
# accuracy_score is:- 96.18213397386364
#
#
# At cv:- 9
# Cross validation score is:- 90.66775611632501
# accuracy_score is:- 96.18213397386364

# %% [markdown]
# # Lets do Hyperparameter Tuning

# %%
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

# %%
lasscv=LassoCV(alphas = None , max_iter =100,normalize=True)
lasscv.fit(X_train,y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
#best alpha paremetere
alpha=lasscv.alpha_
alpha
# Out:
# 0.0005785111423944326

# %%
#Now that we have best parameter,Lets use Lasso regression and see how well our data has fitted before
lasso_reg=Lasso(alpha)
lasso_reg.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.0005785111423944326)

# %%
lasso_reg.score(X_test,y_test)
# Out:
# 0.9618143716033141

# %% [markdown]
# # Using Ridge Regression Model.

# %%
# Ridge will return best alpha and coefficients after performing 10 Cross validation

ridgecv=RidgeCV(alphas =np.arange(0.001,0.1,0.01),normalize=True)
ridgecv.fit(X_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.030999999999999996

# %%
ridge_model = Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.030999999999999996)

# %%
ridge_model.score(X_test,y_test)
# Out:
# 0.9618737458975701

# %%
import pickle
filename=(' Linear Regression Project 1.0')
pickle.dump(lr,open(filename,'wb'))

# %%
loaded_model=pickle.load(open(' Linear Regression Project 1.0','rb'))
result=loaded_model.score(X_test,y_test)
print(result*100)
# Out:
# 96.18213397386364

# %%
conclusion=pd.DataFrame([loaded_model.predict(X_train)[:],pred[:]],index=['predicted','original'])
conclusion
# Out:
#                   0          1          2          3          4          5   \
# predicted  12.350412  10.134727  18.232254  21.149300  12.306310  16.027715
# original   16.126490  23.721319  18.469210  23.323424  18.688223  16.129665
#
#                   6          7          8          9   ...         30  \
# predicted  16.477374  15.773152  10.450905  17.527009  ...  17.443325
# original   14.144811  12.495581  13.140814  10.706931  ...        NaN
#
#                   31         32         33        34         35        36  \
# predicted  18.424549  16.130339  14.600702  8.346649  17.716396  6.653074
# original         NaN        NaN        NaN       NaN        NaN       NaN
#
#                   37         38         39
# predicted  23.181397  16.677989  19.834191
# original         NaN        NaN        NaN
#
# [2 rows x 40 columns]
